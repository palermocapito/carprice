# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
car=pd.read_csv("train-data.csv",index_col=0)

# %%
car.head(20)
# Out:
#                                                 Name    Location  Year  \
# 0                             Maruti Wagon R LXI CNG      Mumbai  2010
# 1                   Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                       Honda Jazz V     Chennai  2011
# 3                                  Maruti Ertiga VDI     Chennai  2012
# 4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5                    Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6                             Nissan Micra Diesel XV      Jaipur  2013
# 7                  Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8                Volkswagen Vento Diesel Comfortline        Pune  2013
# 9                     Tata Indica Vista Quadrajet LS     Chennai  2012
# 10                                  Maruti Ciaz Zeta       Kochi  2018
# 11                       Honda City 1.5 V AT Sunroof     Kolkata  2012
# ...

# %%
car.shape
# Out:
# (6019, 13)

# %%
car.isnull().sum() # Se verifica datos faltantes en nuestro data set
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
missing_data = car.isnull()
missing_data.head(5)
for column in missing_data.columns.values.tolist(): #contando faltantes de cada columna"
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Name
# False    6019
# Name: Name, dtype: int64
#
# Location
# False    6019
# Name: Location, dtype: int64
#
# Year
# False    6019
# Name: Year, dtype: int64
#
# Kilometers_Driven
# False    6019
# Name: Kilometers_Driven, dtype: int64
#
# Fuel_Type
# False    6019
# Name: Fuel_Type, dtype: int64
#
# Transmission
# False    6019
# Name: Transmission, dtype: int64
#
# Owner_Type
# False    6019
# Name: Owner_Type, dtype: int64
#
# Mileage
# False    6017
# True        2
# Name: Mileage, dtype: int64
#
# Engine
# False    5983
# True       36
# Name: Engine, dtype: int64
#
# Power
# False    5983
# True       36
# Name: Power, dtype: int64
#
# Seats
# False    5977
# True       42
# Name: Seats, dtype: int64
#
# New_Price
# True     5195
# False     824
# Name: New_Price, dtype: int64
#
# Price
# False    6019
# Name: Price, dtype: int64

# %%
car["Seats"].mode()
# Out:
# 0    5.0
# dtype: float64

# %%
car["Seats"].fillna(value=5.0,inplace=True)

# %%
car["Power"].mode()
# Out:
# 0    74 bhp
# dtype: object

# %%
car["Power"].fillna(value=74,inplace=True)

# %%
car["Engine"].mode()
# Out:
# 0    1197 CC
# dtype: object

# %%
car["Engine"].fillna(value=1197,inplace=True)

# %%
car["New_Price"].mode()
# Out:
# 0     4.78 Lakh
# 1    63.71 Lakh
# 2    95.13 Lakh
# dtype: object

# %%
car["Mileage"].mode()
# Out:
# 0    17.0 kmpl
# 1    18.9 kmpl
# dtype: object

# %%
car["Mileage"].fillna(value=18.9,inplace=True)

# %%
#Se eliminan  datos de la columna Mileage Kmpl Y km/kg 
#removing kmpl and km/kg from mileage column
car['Mileage'] = car['Mileage'].apply(lambda x: str(x).replace('kmpl', '') if 'kmpl' in str(x) else str(x))
car['Mileage'] = car['Mileage'].apply(lambda x:str(x).replace('km/kg', '') if 'km/kg' in str(x) else str(x))

# %%
#Se eliminan datos CC de la columna engine
car['Engine'] = car['Engine'].apply(lambda x: str(x).replace('CC', '') if 'CC' in str(x) else str(x))

# %%
#se eliminan datos bhp de la columna Power
car['Power'] = car['Power'].apply(lambda x: str(x).replace('bhp', '') if 'bhp' in str(x) else str(x))

# %%
car['Mileage'] = pd.to_numeric(car['Mileage'], errors='coerce')
car['Engine'] = pd.to_numeric(car['Engine'], errors='coerce')
car['Power'] = pd.to_numeric(car['Power'], errors='coerce')

# %%
car.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                 107
# Seats                   0
# New_Price            5195
# Price                   0
# dtype: int64

# %%
car.shape
# Out:
# (6019, 13)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6019 non-null   float64
#  8   Engine             6019 non-null   int64
#  9   Power              5912 non-null   float64
#  10  Seats              6019 non-null   float64
#  11  New_Price          824 non-null    object
#  12  Price              6019 non-null   float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 658.3+ KB

# %%
car["Name"].nunique()
# Out:
# 1876

# %%
car['Brand_Name'] = car['Name'].str.split(' ').str[0]
car.groupby('Brand_Name').nunique() #Se evidencia fila duplicada de la marca ISUZU pero una esta en mayusculas
# Out:
#                Name  Location  Year  Kilometers_Driven  Fuel_Type  \
# Brand_Name
# Ambassador        1         1     1                  1          1
# Audi             69        11    12                180          2
# BMW              87        11    14                190          2
# Bentley           1         1     1                  1          1
# Chevrolet        43        11    15                107          2
# Datsun            9         7     3                 12          1
# Fiat             20         9    11                 26          2
# Force             2         2     1                  2          1
# Ford            114        11    17                237          2
# Honda           154        11    19                415          2
# Hyundai         272        11    19                713          4
# ISUZU             1         2     2                  2          1
# Isuzu             1         1     1                  1          1
# ...

# %%
#Se mezcla Isuzu and ISUZU
car.Brand_Name[car.Brand_Name=='Isuzu']='ISUZU'
# Out:
# C:\Users\TECNIC~1.SOP\AppData\Local\Temp/ipykernel_20476/2919467151.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car.Brand_Name[car.Brand_Name=='Isuzu']='ISUZU'

# %%
car.head(19)
# Out:
#                                    Name    Location  Year  Kilometers_Driven  \
# 0                Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1      Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                          Honda Jazz V     Chennai  2011              46000
# 3                     Maruti Ertiga VDI     Chennai  2012              87000
# 4       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5       Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
# 6                Nissan Micra Diesel XV      Jaipur  2013              86999
# 7     Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016              36000
# 8   Volkswagen Vento Diesel Comfortline        Pune  2013              64430
# 9        Tata Indica Vista Quadrajet LS     Chennai  2012              65932
# 10                     Maruti Ciaz Zeta       Kochi  2018              25692
# ...

# %%
car["Brand_Name"].nunique()
# Out:
# 30

# %%
#dropping the Name ,Location and new_price column
carprice1=car.drop(["Name","Location","New_Price"],axis='columns')

# %%
carprice1.head(20)
# Out:
#     Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# 0   2010              72000       CNG       Manual      First    26.60
# 1   2015              41000    Diesel       Manual      First    19.67
# 2   2011              46000    Petrol       Manual      First    18.20
# 3   2012              87000    Diesel       Manual      First    20.77
# 4   2013              40670    Diesel    Automatic     Second    15.20
# 5   2012              75000       LPG       Manual      First    21.10
# 6   2013              86999    Diesel       Manual      First    23.08
# 7   2016              36000    Diesel    Automatic      First    11.36
# 8   2013              64430    Diesel       Manual      First    20.54
# 9   2012              65932    Diesel       Manual     Second    22.30
# 10  2018              25692    Petrol       Manual      First    21.56
# 11  2012              60000    Petrol    Automatic      First    16.80
# ...

# %%
missing_data = carprice1.isnull()
missing_data.head(5)
for column in missing_data.columns.values.tolist(): #contando faltantes de cada columna"
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Year
# False    6019
# Name: Year, dtype: int64
#
# Kilometers_Driven
# False    6019
# Name: Kilometers_Driven, dtype: int64
#
# Fuel_Type
# False    6019
# Name: Fuel_Type, dtype: int64
#
# Transmission
# False    6019
# Name: Transmission, dtype: int64
#
# Owner_Type
# False    6019
# Name: Owner_Type, dtype: int64
#
# Mileage
# False    6019
# Name: Mileage, dtype: int64
#
# Engine
# False    6019
# Name: Engine, dtype: int64
#
# Power
# False    5912
# True      107
# Name: Power, dtype: int64
#
# Seats
# False    6019
# Name: Seats, dtype: int64
#
# Price
# False    6019
# Name: Price, dtype: int64
#
# Brand_Name
# False    6019
# Name: Brand_Name, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.heatmap(carprice1.isnull())
plt.show()#NO hay datos faltantes en el data set, esta listo para el analisis

# %%
carprice1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6019 entries, 0 to 6018
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               6019 non-null   int64
#  1   Kilometers_Driven  6019 non-null   int64
#  2   Fuel_Type          6019 non-null   object
#  3   Transmission       6019 non-null   object
#  4   Owner_Type         6019 non-null   object
#  5   Mileage            6019 non-null   float64
#  6   Engine             6019 non-null   int64
#  7   Power              5912 non-null   float64
#  8   Seats              6019 non-null   float64
#  9   Price              6019 non-null   float64
#  10  Brand_Name         6019 non-null   object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 564.3+ KB

# %%
carprice1['Power'] = pd.to_numeric(carprice1['Power'], errors='coerce')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(carprice1["Power"])

# set x/y labels and plot title
plt.pyplot.xlabel("Power")
plt.pyplot.ylabel("count")
plt.pyplot.title("Power bins")
# Out:
# Text(0.5, 1.0, 'Power bins')

# %%
#se contruye un grafico con el maximo y minimo de "horsepower"
bins = np.linspace(min(carprice1["Power"]), max(carprice1["Power"]), 4)
bins
# Out:
# array([ 34.2       , 209.46666667, 384.73333333, 560.        ])

# %%
group_names = ['Low', 'Medium', 'High']# se establece el nombre de los grupos

# %%
carprice1['Power-binned'] = pd.cut(carprice1['Power'], bins, labels=group_names, include_lowest=True )
carprice1[['Power','Power-binned']].head(20)
# Out:
#      Power Power-binned
# 0    58.16          Low
# 1   126.20          Low
# 2    88.70          Low
# 3    88.76          Low
# 4   140.80          Low
# 5    55.20          Low
# 6    63.10          Low
# 7   171.50          Low
# 8   103.60          Low
# 9    74.00          Low
# 10  103.25          Low
# 11  116.30          Low
# 12   74.00          Low
# 13  187.70          Low
# 14  115.00          Low
# 15  175.56          Low
# 16   98.60          Low
# 17   74.00          Low
# 18   83.80          Low
# 19  167.62          Low

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, carprice1["Power-binned"].value_counts())

# set x/y para grafico de barras
plt.pyplot.xlabel("Power")
plt.pyplot.ylabel("count")
plt.pyplot.title("Power bins")
# Out:
# Text(0.5, 1.0, 'Power bins')

# %%
# Marcas vs precios, podemos ver que las marcas de carros deportivos son las mas costosas  ###variable categorica###
sns.boxplot (x="Brand_Name", y="Price", data=carprice1)
plt.rcParams["figure.figsize"] = (20, 20)
plt.plot([[5,35], [5, 35]])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\TECNIC~1.SOP\AppData\Local\Temp/ipykernel_20476/2308767129.py in <module>
#       2 sns.boxplot (x="Brand_Name", y="Price", data=carprice1)
#       3 plt.rcParams["figure.figsize"] = (20, 20)
# ----> 4 plt.plot([[5,35], [5, 35]])
#       5 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
#Marcas mas vendidas  de autos en la india 
# %matplotlib inline
import matplotlib as plt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel("Brand_Name")
plt.ylabel("Count of Car")
carprice1["Brand_Name"].value_counts().plot(kind="bar",title="Brand vs car count",color="red")
plt.grid(color="black",linestyle="-.", linewidth=0.7)

# %%
#Las marcas más vendidas en la india son Maruti y Hiunday

# %%
plt.xlabel("Year")
plt.ylabel("Count of Car")
carprice1["Year"].value_counts().plot(kind="bar",title="Year vs car count",color="red")
plt.grid(color="black",linestyle="-.", linewidth=0.7)

# %%
# Este data set contiene Vehiculos de modelos 1998-2014 siendo 2014 el modelo con mas vehiculos

# %%
# ANALISIS DE OTRAS CARACTERISTICAS DE LOS VEHICULOS, Tipo de Combustible,Trassmision,
# %matplotlib inline
import matplotlib as plt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


plt.xlabel("Fuel_Type")
plt.ylabel("Count of Car")
carprice1["Fuel_Type"].value_counts().plot(kind="bar",title="Fuel_Type vs car count",color="red")
plt.grid(color="black",linestyle="-.", linewidth=0.7)
plt.xlabel("Fuel_Type")
plt.ylabel("Count of Car")
carprice1["Fuel_Type"].value_counts().plot(kind="bar",title="Fuel_Type vs car count",color="red")
plt.grid(color="black",linestyle="-.", linewidth=0.7)

# %%
plt.xlabel("Transmission")
plt.ylabel("Count of Car")
carprice1["Transmission"].value_counts().plot(kind="bar",title="Transmission vs car count",color="green")
plt.grid(color="black",linestyle="-.", linewidth=0.7)

# %%
# Es predominante la trasnmision mecanica en data set de vehiculos usados

# %%
#Numero de propietarios
plt.xlabel("Owner_Type")
plt.ylabel("Count of car")
carprice1['Owner_Type'].value_counts().plot(kind='bar',title='Owner_Type vs car count',color='blue')
plt.grid(linestyle='-.')

# %%
#Cantidad de asientos
plt.xlabel("No of seats")
plt.ylabel("Count of car")
carprice1['Seats'].value_counts().plot(kind='bar',title='Number of seats vs car count',color='cyan')
plt.grid(linestyle='-.')

# %%
#Marca vs Precio 
BrandVsPrice=pd.DataFrame(carprice1.groupby("Brand_Name")["Price"].mean())
BrandVsPrice.plot.bar(color="tomato",figsize=(11,5))
plt.grid(linestyle="-.")
plt.show()

# %%
#Lamborghini es la marca mas costosa en el data set

# %%
# Kilometros rrecorridos "mileage""price"
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="Mileage", y="Price", data=carprice1)
plt.ylim(0,)
# Out:
# (0.0, 168.24989512259017)

# %%
#year vs price
plt.title("Year vs Price")
plt.xlabel("Year")
plt.ylabel("Price")
plt.scatter(cardf.Year,cardf.Price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\TECNIC~1.SOP\AppData\Local\Temp/ipykernel_20476/3480042841.py in <module>
#       3 plt.xlabel("Year")
#       4 plt.ylabel("Price")
# ----> 5 plt.scatter(cardf.Year,cardf.Price)
#
# NameError: name 'cardf' is not defined

# %%
carprice1.isin([0]).sum()
# Out:
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                   0
# Price                   0
# Brand_Name              0
# Power-binned            0
# Fuel_Type_n            56
# Transmission_n       1719
# Owner_Type_n         4928
# Brand_Name_n            1
# dtype: int64

# %%
carprice1.drop(carprice1[carprice1['Seats']==0].index,axis=0,inplace=True)

# %%
#we have already calculated the mode of milage column for filling #null values which is 17.0
carprice1["Mileage"].replace({0.0:17.0 },inplace=True)

# %%
carprice1.isin([0]).sum()
# Out:
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                   0
# Seats                   0
# Price                   0
# Brand_Name              0
# Power-binned            0
# Fuel_Type_n            56
# Transmission_n       1719
# Owner_Type_n         4928
# Brand_Name_n            1
# dtype: int64

# %%
# Se crea un nuevo data frame
carprice2=carprice1

# %%
from sklearn.preprocessing import LabelEncoder
le_Fuel_Type=LabelEncoder()
le_Transmission=LabelEncoder()
le_Owner_Type=LabelEncoder()
le_Brand_Name=LabelEncoder()
carprice2['Fuel_Type_n']= le_Fuel_Type.fit_transform(carprice2['Fuel_Type'])
carprice2['Transmission_n']=le_Transmission.fit_transform(carprice2['Transmission'])
carprice2['Owner_Type_n']=le_Owner_Type.fit_transform(carprice2['Owner_Type'])
carprice2['Brand_Name_n']=le_Brand_Name.fit_transform(carprice2['Brand_Name'])

# %%
carprice2.head(1)
# Out:
#    Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0  2010              72000       CNG       Manual      First     26.6     998
#
#    Power  Seats  Price Brand_Name Power-binned  Fuel_Type_n  Transmission_n  \
# 0  58.16    5.0   1.75     Maruti          Low            0               1
#
#    Owner_Type_n  Brand_Name_n
# 0             0            17

# %%
carprice2=carprice2.drop(["Fuel_Type","Transmission","Owner_Type","Brand_Name"],axis='columns')

# %%
carprice2.head(1)
# Out:
#    Year  Kilometers_Driven  Mileage  Engine  Power  Seats  Price Power-binned  \
# 0  2010              72000     26.6     998  58.16    5.0   1.75          Low
#
#    Fuel_Type_n  Transmission_n  Owner_Type_n  Brand_Name_n
# 0            0               1             0            17

# %%
carprice2=carprice2[['Brand_Name_n','Year','Kilometers_Driven','Fuel_Type_n','Transmission_n','Owner_Type_n','Mileage','Engine','Power','Seats','Price']]

# %%
carprice2.head(1)
# Out:
#    Brand_Name_n  Year  Kilometers_Driven  Fuel_Type_n  Transmission_n  \
# 0            17  2010              72000            0               1
#
#    Owner_Type_n  Mileage  Engine  Power  Seats  Price
# 0             0     26.6     998  58.16    5.0   1.75

# %%
corrMatrix =carprice2.corr()
plt.figure(figsize=(10,7))
sns.heatmap(corrMatrix, annot=True,cmap= 'coolwarm', linewidths=3, linecolor='black')
plt.show()

# %%
carprice2predic=carprice2.drop(["Price"],axis="columns")
carprice2target=carprice2["Price"]

# %%
carprice2predic.head(6)
# Out:
#    index  Brand_Name_n  Year  Kilometers_Driven  Fuel_Type_n  Transmission_n  \
# 0      0            17  2010              72000            0               1
# 1      1            10  2015              41000            1               1
# 2      2             9  2011              46000            4               1
# 3      3            17  2012              87000            1               1
# 4      4             1  2013              40670            1               0
# 5      5            10  2012              75000            3               1
#
#    Owner_Type_n  Mileage  Engine   Power  Seats
# 0             0    26.60     998   58.16    5.0
# 1             0    19.67    1582  126.20    5.0
# 2             0    18.20    1199   88.70    5.0
# 3             0    20.77    1248   88.76    7.0
# 4             2    15.20    1968  140.80    5.0
# 5             0    21.10     814   55.20    5.0

# %%
carprice2target.head(6)
# Out:
# 0     1.75
# 1    12.50
# 2     4.50
# 3     6.00
# 4    17.74
# 5     2.35
# Name: Price, dtype: float64

# %%
carprice2= carprice2.reset_index()

# %%
carprice2predic=carprice2.drop(["Price"],axis="columns")
carprice2target=carprice2["Price"]

# %%
carprice2[np.isfinite(carprice2) == True] = 0

# %%
def clean_dataset(carprice2):
    assert isinstance(carprice2, pd.DataFrame), "df needs to be a pd.DataFrame"
    carprice2.dropna(inplace=True)
    indices_to_keep = ~carprice2target.isin([np.nan, np.inf, -np.inf]).any(1)
    return carprice2[indices_to_keep].astype(np.float64)

# %%
carprice2.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
carprice2 = carprice2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(carprice2predic,carprice2target)
#use inbuilt class feature_importances of ExtraTreeRegressor
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=carprice2predic.columns)
plt.figure(figsize=(11,5))
plt.xlabel("Value")
plt.ylabel("Features")
plt.title("Features vs Importance")
plt.grid(feat_importances.nlargest(10)).plot(kind='barh',color='#D98880')##45B39D
plt.grid(color='black', linestyle='-.', linewidth=0.7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\TECNIC~1.SOP\AppData\Local\Temp/ipykernel_20476/300589874.py in <module>
#      10 plt.ylabel("Features")
#      11 plt.title("Features vs Importance")
# ---> 12 plt.grid(feat_importances.nlargest(10)).plot(kind='barh',color='#D98880')##45B39D
#      13 plt.grid(color='black', linestyle='-.', linewidth=0.7)
#      14 plt.show()
#
# AttributeError: 'NoneType' object has no attribute 'plot'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
# ...
